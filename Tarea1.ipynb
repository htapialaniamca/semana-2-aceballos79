# %% [markdown]
# # Computo de Alto Desempeño
# ## Tarea 1
# ## Ceballos Alberto

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import ipyparallel as ipp
# %matplotlib inline

# %%
c =  ipp.Client()

# %%
c.ids
# Out:
# [0, 1, 2, 3]

# %%
PrimeQ = lambda x: all(x % i != 0 for i in range(int(x**0.5)+1)[2:]) and x>1

# %%
dview = c[:]

# %%
dview
# Out:
# <DirectView [0, 1, 2, 3]>

# %%
list = dview.map_sync(lambda x: all(x % i != 0 for i in range(int(x**0.5)+1)[2:]) and x>1, range (5000))
list
for n in range(5000):
    if (list[n] == True):
        print 2*n-1
# Out:
# 3
# 5
# 9
# 13
# 21
# 25
# 33
# 37
# 45
# 57
# 61
# 73
# 81
# 85
# 93
# 105
# 117
# 121
# 133
# 141
# 145
# 157
# 165
# 177
# 193
# 201
# 205
# 213
# 217
# 225
# 253
# 261
# 273
# 277
# 297
# 301
# 313
# 325
# 333
# 345
# 357
# 361
# 381
# 385
# 393
# 397
# 421
# 445
# 453
# 457
# 465
# 477
# 481
# 501
# 513
# 525
# 537
# 541
# 553
# 561
# 565
# 585
# 613
# 621
# 625
# 633
# 661
# 673
# 693
# 697
# 705
# 717
# 733
# 745
# 757
# 765
# 777
# 793
# 801
# 817
# 837
# 841
# 861
# 865
# 877
# 885
# 897
# 913
# 921
# 925
# 933
# 957
# 973
# 981
# 997
# 1005
# 1017
# 1041
# 1045
# 1081
# 1093
# 1113
# 1125
# 1137
# 1141
# 1153
# 1173
# 1185
# 1197
# 1201
# 1213
# 1225
# 1233
# 1237
# 1261
# 1281
# 1285
# 1293
# 1305
# 1317
# 1321
# 1345
# 1353
# 1365
# 1381
# 1401
# 1417
# 1437
# 1453
# 1465
# 1477
# 1485
# 1501
# 1513
# 1521
# 1537
# 1545
# 1573
# 1593
# 1617
# 1621
# 1641
# 1645
# 1653
# 1657
# 1677
# 1705
# 1713
# 1717
# 1725
# 1753
# 1761
# 1765
# 1773
# 1813
# 1821
# 1837
# 1857
# 1873
# ...

# %%
# %timeit lista = [PrimeQ(2**n-1) for n in range(50)]
for i in range(50):
    if (lista[i] == True):
        print i
# Out:
# 1 loop, best of 3: 2.08 s per loop
# 2
# 3
# 5
# 7
# 13
# 17
# 19
# 31

# %%
# %timeit lista = [PrimeQ(2**n-1) for n in range(50)]
for i in range(50):
    if (lista[i] == True):
        print 2**i-1
# Out:
# 1 loop, best of 3: 2.07 s per loop
# 3
# 7
# 31
# 127
# 8191
# 131071
# 524287
# 2147483647
